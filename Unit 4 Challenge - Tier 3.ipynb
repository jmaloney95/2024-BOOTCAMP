995-07-01 00:00:00  1995-08-01 00:00:00
# City of London                110128.0423          112329.4376
# Barking & Dagenham            52113.12157          52232.19868
# Barnet                        91441.24768          92361.31512
# Bexley                        63722.70055          64432.60005
# Brent                         74127.03788           73547.0411
# Bromley                       82898.52264          82054.37156
# Camden                        124027.5768          125529.8039
# Croydon                       69142.48112          68993.42545
# Ealing                         82352.2226          82706.65927
# Enfield                       71837.54011          72237.94562
# Greenwich                     65486.34112          65076.43195
# Hackney                         68390.753          68096.79385
# Hammersmith & Fulham          124381.5134          123625.3196
# Haringey                      80746.34881          81217.69074
# Harrow                        84226.69844          84430.61796
# Havering                      68680.83996          69023.36482
# Hillingdon                    74671.13263          74967.86534
# Hounslow                      73717.78844          74479.94802
# Islington                     98976.14077          98951.20791
# Kensington & Chelsea          197963.3169          198037.4218
# Kingston upon Thames            82525.793          83342.84552
# Lambeth                       69608.72242          68840.02827
# Lewisham                      58126.37811           58151.3154
# Merton                        81055.90335          80781.09186
# Newham                        55458.31693          54709.35467
# Redbridge                     72880.83974          73275.16891
# Richmond upon Thames          114656.6011          112320.4096
# Southwark                     67024.74767          65525.94434
# Sutton                        70789.57284          69958.41918
# Tower Hamlets                 64692.22672          63472.27558
# Waltham Forest                61933.52738           61916.4222
# Wandsworth                    89830.58934          90560.68078
# Westminster                   133450.2162          136581.5082
# Unnamed: 34                           NaN                  NaN
# Inner London                  80550.47935          80597.64563
# Outer London                  73665.90517          73691.12888
# Unnamed: 37                           NaN                  NaN
# NORTH EAST                    43287.74323          41899.05494
# NORTH WEST                    44109.58764          44193.66583
# YORKS & THE HUMBER            45534.99864          45111.45939
# EAST MIDLANDS                 46037.67312          45922.53585
# WEST MIDLANDS                 49860.00809          49598.45969
# EAST OF ENGLAND               57242.30186          56732.40547
# LONDON                        75984.24079          75529.34488
# SOUTH EAST                    65224.88465          64851.60429
# SOUTH WEST                    54265.86368          54365.71495
# Unnamed: 47                           NaN                  NaN
# England                       53900.60633          53600.31975
#
#                                       9    ...                  343  \
# Unnamed: 0            1995-09-01 00:00:00  ...  2023-07-01 00:00:00
# City of London                104473.1096  ...              1008012
# Barking & Dagenham            51471.61353  ...               338138
# Barnet                        93273.12245  ...               589701
# Bexley                        64509.54767  ...               397933
# Brent                         73789.54287  ...               512835
# Bromley                       81440.43008  ...               500124
# Camden                        120596.8511  ...               838133
# Croydon                       69393.50023  ...               397275
# Ealing                        82011.08271  ...               517267
# Enfield                       71725.22104  ...               435701
# Greenwich                     63996.81525  ...               427423
# Hackney                       68752.50284  ...               609715
# Hammersmith & Fulham          123094.0484  ...               852824
# Haringey                      82142.89052  ...               591986
# Harrow                        83606.97863  ...               501749
# Havering                        68108.186  ...               419357
# Hillingdon                    73843.55239  ...               452135
# Hounslow                       74426.6609  ...               450354
# Islington                     99582.63778  ...               692982
# Kensington & Chelsea          197047.8333  ...              1391128
# Kingston upon Thames          85110.96835  ...               540997
# Lambeth                       70155.81997  ...               533879
# Lewisham                      58742.99034  ...               441178
# Merton                        80824.70075  ...               572412
# Newham                        54585.50364  ...               400286
# Redbridge                     73204.02373  ...               453684
# Richmond upon Thames          110424.5703  ...               754746
# Southwark                     63467.00948  ...               487658
# Sutton                        69937.40214  ...               430137
# Tower Hamlets                 62177.59435  ...               443084
# Waltham Forest                61548.15206  ...               481907
# Wandsworth                     91373.6984  ...               606586
# Westminster                   135993.0705  ...              1114016
# Unnamed: 34                           NaN  ...                  NaN
# Inner London                     80402.85  ...               605132
# Outer London                  73454.44292  ...               475359
# Unnamed: 37                           NaN  ...                  NaN
# NORTH EAST                    41850.85646  ...               158868
# NORTH WEST                    44088.07696  ...               213724
# YORKS & THE HUMBER            44837.86023  ...               207706
# EAST MIDLANDS                 45771.66321  ...               243006
# WEST MIDLANDS                 49319.69715  ...               248046
# EAST OF ENGLAND               56259.28635  ...               339626
# LONDON                        74940.80872  ...               522211
# SOUTH EAST                    64352.47119  ...               378132
# SOUTH WEST                    54243.98694  ...               314745
# Unnamed: 47                           NaN  ...                  NaN
# England                        53309.2331  ...               300591
#
#                                       344                  345  \
# Unnamed: 0            2023-08-01 00:00:00  2023-09-01 00:00:00
# City of London                     936702               896682
# Barking & Dagenham                 339563               337649
# Barnet                             591563               588233
# Bexley                             396647               397348
# Brent                              530319               529274
# Bromley                            499729               499642
# Camden                             852687               830426
# Croydon                            401244               405991
# Ealing                             524049               526093
# Enfield                            438860               447513
# Greenwich                          439990               436194
# Hackney                            590977               583729
# Hammersmith & Fulham               815030               805877
# Haringey                           591344               588279
# Harrow                             505419               508669
# Havering                           417167               417654
# Hillingdon                         454549               452371
# Hounslow                           463807               472959
# Islington                          694548               702999
# Kensington & Chelsea              1394669              1348024
# Kingston upon Thames               545951               546679
# Lambeth                            544400               561994
# Lewisham                           448132               454712
# Merton                             574101               567928
# Newham                             398622               411348
# Redbridge                          472739               489455
# Richmond upon Thames               754976               760474
# Southwark                          483002               492803
# Sutton                             428567               432819
# Tower Hamlets                      445315               449404
# Waltham Forest                     489569               492053
# Wandsworth                         610705               625446
# Westminster                       1053006              1003838
# Unnamed: 34                           NaN                  NaN
# Inner London                       602865               605775
# Outer London                       479709               481766
# Unnamed: 37                           NaN                  NaN
# NORTH EAST                         162969               159782
# NORTH WEST                         214387               214684
# YORKS & THE HUMBER                 210372               206904
# EAST MIDLANDS                      246101               244400
# WEST MIDLANDS                      249530               249940
# EAST OF ENGLAND                    339742               340046
# LONDON                             523760               525847
# SOUTH EAST                         380337               378595
# SOUTH WEST                         319026               316487
# Unnamed: 47                           NaN                  NaN
# England                            302916               301659
#
#                                       346                  347  \
# Unnamed: 0            2023-10-01 00:00:00  2023-11-01 00:00:00
# City of London                     854727               837486
# Barking & Dagenham                 337933               341026
# Barnet                             579669               581615
# Bexley                             393723               398080
# Brent                              528081               515182
# Bromley                            497486               493017
# Camden                             838450               836887
# Croydon                            397704               388572
# Ealing                             523924               511254
# Enfield                            442258               439840
# Greenwich                          428554               425440
# Hackney                            590493               600463
# Hammersmith & Fulham               777113               769306
# Haringey                           581749               580813
# Harrow                             515824               511718
# Havering                           417002               415346
# Hillingdon                         447776               445760
# Hounslow                           464900               456525
# Islington                          706094               695478
# Kensington & Chelsea              1395439              1316266
# Kingston upon Thames               551537               540507
# Lambeth                            550889               541778
# Lewisham                           449217               440002
# Merton                             563966               564792
# Newham                             407678               408861
# Redbridge                          485880               483693
# Richmond upon Thames               757010               742948
# Southwark                          492605               495244
# Sutton                             433604               426067
# Tower Hamlets                      449941               446412
# Waltham Forest                     494510               489697
# Wandsworth                         629859               640858
# Westminster                       1012549              1005566
# Unnamed: 34                           NaN                  NaN
# Inner London                       604686               601084
# Outer London                       478641               474190
# Unnamed: 37                           NaN                  NaN
# NORTH EAST                
# Unnamed: 37                           NaN                  NaN
# NORTH EAST                         159084               157155
# NORTH WEST                         213455               215189
# YORKS & THE HUMBER                 205271               206052
# EAST MIDLANDS                      241168               240446
# WEST MIDLANDS                      243502               245345
# EAST OF ENGLAND                    338133               337949
# LONDON                             506611               502703
# SOUTH EAST                         371224               369974
# SOUTH WEST                         314147               314378
# Unnamed: 47                           NaN                  NaN
# England                            297245               297199
#
#                                       352
# Unnamed: 0            2024-04-01 00:00:00
# City of London                     778946
# Barking & Dagenham                 333425
# Barnet                             573010
# Bexley                             404557
# Brent                              488462
# Bromley                            485561
# Camden                             762130
# Croydon                            398216
# Ealing                             514465
# Enfield                            406161
# Greenwich                          442117
# Hackney                            611025
# Hammersmith & Fulham               766538
# Haringey                           523150
# Harrow                             513235
# Havering                           406085
# Hillingdon                         445707
# Hounslow                           449866
# Islington                          668635
# Kensington & Chelsea              1109723
# Kingston upon Thames               532281
# Lambeth                            512463
# Lewisham                           425774
# Merton                             553367
# Newham                             402435
# Redbridge                          458781
# Richmond upon Thames               725536
# Southwark                          467676
# Sutton                             420492
# Tower Hamlets                      440574
# Waltham Forest                     477622
# Wandsworth                         620731
# Westminster                        969527
# Unnamed: 34                           NaN
# Inner London                       574168
# Outer London                       467468
# Unnamed: 37                           NaN
# NORTH EAST                         158133
# NORTH WEST                         216714
# YORKS & THE HUMBER                 203110
# EAST MIDLANDS                      242132
# WEST MIDLANDS                      246292
# EAST OF ENGLAND                    335448
# LONDON                             501880
# SOUTH EAST                         375067
# SOUTH WEST                         317911
# Unnamed: 47                           NaN
# England                            298229
#
# [49 rows x 353 columns]

# %%
properties_T.index
properties_T.columns
# Out:
# RangeIndex(start=0, stop=353, step=1)

# %%
properties_T = properties_T.reset_index()

# %%
properties_T.head()
# Out:
#                 index          0                    1                    2  \
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001          91448.98487          82202.77314
# 2  Barking & Dagenham  E09000002           50460.2266          51085.77983
# 3              Barnet  E09000003          93284.51832          93190.16963
# 4              Bexley  E09000004          64958.09036          64787.92069
#
#                      3                    4                    5  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1          79120.70256          77101.20804          84409.14932
# 2          51268.96956          53133.50526          53042.24852
# 3          92247.52435          90762.87492          90258.00033
# 4          64367.49344          64277.66881          63997.13588
#
#                      6                    7                    8  ...  \
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...
# 1          94900.51244          110128.0423          112329.4376  ...
# 2          53700.34831          52113.12157          52232.19868  ...
# 3          90107.23471          91441.24768          92361.31512  ...
# 4          64252.32335          63722.70055          64432.60005  ...
#
#                    343                  344                  345  \
# 0  2023-07-01 00:00:00  2023-08-01 00:00:00  2023-09-01 00:00:00
# 1              1008012               936702               896682
# 2               338138               339563               337649
# 3               589701               591563               588233
# 4               397933               396647               397348
#
#                    346                  347                  348  \
# 0  2023-10-01 00:00:00  2023-11-01 00:00:00  2023-12-01 00:00:00
# 1               854727               837486               804808
# 2               337933               341026               337725
# 3               579669               581615               581371
# 4               393723               398080               394474
#
#                    349                  350                  351  \
# 0  2024-01-01 00:00:00  2024-02-01 00:00:00  2024-03-01 00:00:00
# 1               798179               785962               755712
# 2               328359               319809               326650
# 3               581246               573653               582371
# 4               395468               395439               400146
#
#                    352
# 0  2024-04-01 00:00:00
# 1               778946
# 2               333425
# 3               573010
# 4               404557
#
# [5 rows x 354 columns]

# %%
properties_T.iloc[[0]]
# Out:
#         index    0                    1                    2  \
# 0  Unnamed: 0  NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
#
#                      3                    4                    5  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
#
#                      6                    7                    8  ...  \
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...
#
#                    343                  344                  345  \
# 0  2023-07-01 00:00:00  2023-08-01 00:00:00  2023-09-01 00:00:00
#
#                    346                  347                  348  \
# 0  2023-10-01 00:00:00  2023-11-01 00:00:00  2023-12-01 00:00:00
#
#                    349                  350                  351  \
# 0  2024-01-01 00:00:00  2024-02-01 00:00:00  2024-03-01 00:00:00
#
#                    352
# 0  2024-04-01 00:00:00
#
# [1 rows x 354 columns]

# %%
properties_T.columns = properties_T.iloc[0]

# %%
properties_T.columns
# Out:
# Index([       'Unnamed: 0',                 NaT, 1995-01-01 00:00:00,
#        1995-02-01 00:00:00, 1995-03-01 00:00:00, 1995-04-01 00:00:00,
#        1995-05-01 00:00:00, 1995-06-01 00:00:00, 1995-07-01 00:00:00,
#        1995-08-01 00:00:00,
#        ...
#        2023-07-01 00:00:00, 2023-08-01 00:00:00, 2023-09-01 00:00:00,
#        2023-10-01 00:00:00, 2023-11-01 00:00:00, 2023-12-01 00:00:00,
#        2024-01-01 00:00:00, 2024-02-01 00:00:00, 2024-03-01 00:00:00,
#        2024-04-01 00:00:00],
#       dtype='object', name=0, length=354)

# %%
properties_T.head()
# Out:
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00  \
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001          91448.98487          82202.77314
# 2  Barking & Dagenham  E09000002           50460.2266          51085.77983
# 3              Barnet  E09000003          93284.51832          93190.16963
# 4              Bexley  E09000004          64958.09036          64787.92069
#
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1          79120.70256          77101.20804          84409.14932
# 2          51268.96956          53133.50526          53042.24852
# 3          92247.52435          90762.87492          90258.00033
# 4          64367.49344          64277.66881          63997.13588
#
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...  \
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...
# 1          94900.51244          110128.0423          112329.4376  ...
# 2          53700.34831          52113.12157          52232.19868  ...
# 3          90107.23471          91441.24768          92361.31512  ...
# 4          64252.32335          63722.70055          64432.60005  ...
#
# 0  2023-07-01 00:00:00  2023-08-01 00:00:00  2023-09-01 00:00:00  \
# 0  2023-07-01 00:00:00  2023-08-01 00:00:00  2023-09-01 00:00:00
# 1              1008012               936702               896682
# 2               338138               339563               337649
# 3               589701               591563               588233
# 4               397933               396647               397348
#
# 0  2023-10-01 00:00:00  2023-11-01 00:00:00  2023-12-01 00:00:00  \
# 0  2023-10-01 00:00:00  2023-11-01 00:00:00  2023-12-01 00:00:00
# 1               854727               837486               804808
# 2               337933               341026               337725
# 3               579669               581615               581371
# 4               393723               398080               394474
#
# 0  2024-01-01 00:00:00  2024-02-01 00:00:00  2024-03-01 00:00:00  \
# 0  2024-01-01 00:00:00  2024-02-01 00:00:00  2024-03-01 00:00:00
# 1               798179               785962               755712
# 2               328359               319809               326650
# 3               581246               573653               582371
# 4               395468               395439               400146
#
# 0  2024-04-01 00:00:00
# 0  2024-04-01 00:00:00
# 1               778946
# 2               333425
# 3               573010
# 4               404557
#
# [5 rows x 354 columns]

# %%
properties_T = properties_T.drop(0)

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
properties_T = properties_T.rename(columns = {'Unnamed: 0':'London_Borough', pd.NaT: 'ID'})
properties_T.head()
# Out:
# 0      London_Borough         ID 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001         91448.98487         82202.77314
# 2  Barking & Dagenham  E09000002          50460.2266         51085.77983
# 3              Barnet  E09000003         93284.51832         93190.16963
# 4              Bexley  E09000004         64958.09036         64787.92069
# 5               Brent  E09000005         71306.56698         72022.26197
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1         79120.70256         77101.20804         84409.14932
# 2         51268.96956         53133.50526         53042.24852
# 3         92247.52435         90762.87492         90258.00033
# 4         64367.49344         64277.66881         63997.13588
# 5         72015.76274         72965.63094         73704.04743
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1         94900.51244         110128.0423         112329.4376  ...
# 2         53700.34831         52113.12157         52232.19868  ...
# 3         90107.23471         91441.24768         92361.31512  ...
# 4         64252.32335         63722.70055         64432.60005  ...
# 5         74310.48167         74127.03788          73547.0411  ...
#
# 0 2023-07-01 00:00:00 2023-08-01 00:00:00 2023-09-01 00:00:00  \
# 1             1008012              936702              896682
# 2              338138              339563              337649
# 3              589701              591563              588233
# 4              397933              396647              397348
# 5              512835              530319              529274
#
# 0 2023-10-01 00:00:00 2023-11-01 00:00:00 2023-12-01 00:00:00  \
# 1              854727              837486              804808
# 2              337933              341026              337725
# 3              579669              581615              581371
# 4              393723              398080              394474
# 5              528081              515182              507592
#
# 0 2024-01-01 00:00:00 2024-02-01 00:00:00 2024-03-01 00:00:00  \
# 1              798179              785962              755712
# 2              328359              319809              326650
# 3              581246              573653              582371
# 4              395468              395439              400146
# 5              520722              527606              510427
#
# 0 2024-04-01 00:00:00
# 1              778946
# 2              333425
# 3              573010
# 4              404557
# 5              488462
#
# [5 rows x 354 columns]

# %%
properties_T.columns
# Out:
# Index([   'London_Borough',                'ID', 1995-01-01 00:00:00,
#        1995-02-01 00:00:00, 1995-03-01 00:00:00, 1995-04-01 00:00:00,
#        1995-05-01 00:00:00, 1995-06-01 00:00:00, 1995-07-01 00:00:00,
#        1995-08-01 00:00:00,
#        ...
#        2023-07-01 00:00:00, 2023-08-01 00:00:00, 2023-09-01 00:00:00,
#        2023-10-01 00:00:00, 2023-11-01 00:00:00, 2023-12-01 00:00:00,
#        2024-01-01 00:00:00, 2024-02-01 00:00:00, 2024-03-01 00:00:00,
#        2024-04-01 00:00:00],
#       dtype='object', name=0, length=354)

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
clean_properties = pd.melt(properties_T, id_vars= ['London_Borough', 'ID'])

# %%
clean_properties.head()
# Out:
#        London_Borough         ID                    0        value
# 0      City of London  E09000001  1995-01-01 00:00:00  91448.98487
# 1  Barking & Dagenham  E09000002  1995-01-01 00:00:00   50460.2266
# 2              Barnet  E09000003  1995-01-01 00:00:00  93284.51832
# 3              Bexley  E09000004  1995-01-01 00:00:00  64958.09036
# 4               Brent  E09000005  1995-01-01 00:00:00  71306.56698

# %%
clean_properties = clean_properties.rename(columns = {0: 'Month', 'value': 'Average_price'})

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
clean_properties.dtypes
clean_properties.count()
# Out:
# London_Borough    16896
# ID                15840
# Month             16896
# Average_price     15840
# dtype: int64

# %%
clean_properties
# Out:
#            London_Borough         ID                Month Average_price
# 0          City of London  E09000001  1995-01-01 00:00:00   91448.98487
# 1      Barking & Dagenham  E09000002  1995-01-01 00:00:00    50460.2266
# 2                  Barnet  E09000003  1995-01-01 00:00:00   93284.51832
# 3                  Bexley  E09000004  1995-01-01 00:00:00   64958.09036
# 4                   Brent  E09000005  1995-01-01 00:00:00   71306.56698
# ...                   ...        ...                  ...           ...
# 16891              LONDON  E12000007  2024-04-01 00:00:00        501880
# 16892          SOUTH EAST  E12000008  2024-04-01 00:00:00        375067
# 16893          SOUTH WEST  E12000009  2024-04-01 00:00:00        317911
# 16894         Unnamed: 47        NaN  2024-04-01 00:00:00           NaN
# 16895             England  E92000001  2024-04-01 00:00:00        298229
#
# [16896 rows x 4 columns]

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
clean_properties['London_Borough'].unique()
# Out:
# array(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley',
#        'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey',
#        'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth',
#        'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster', 'Unnamed: 34',
#        'Inner London', 'Outer London', 'Unnamed: 37', 'NORTH EAST',
#        'NORTH WEST', 'YORKS & THE HUMBER', 'EAST MIDLANDS',
#        'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST',
#        'SOUTH WEST', 'Unnamed: 47', 'England'], dtype=object)

# %%
clean_properties[clean_properties['ID'].isna()]
# Out:
#       London_Borough   ID                Month Average_price
# 33       Unnamed: 34  NaN  1995-01-01 00:00:00           NaN
# 36       Unnamed: 37  NaN  1995-01-01 00:00:00           NaN
# 46       Unnamed: 47  NaN  1995-01-01 00:00:00           NaN
# 81       Unnamed: 34  NaN  1995-02-01 00:00:00           NaN
# 84       Unnamed: 37  NaN  1995-02-01 00:00:00           NaN
# ...              ...  ...                  ...           ...
# 16836    Unnamed: 37  NaN  2024-03-01 00:00:00           NaN
# 16846    Unnamed: 47  NaN  2024-03-01 00:00:00           NaN
# 16881    Unnamed: 34  NaN  2024-04-01 00:00:00           NaN
# 16884    Unnamed: 37  NaN  2024-04-01 00:00:00           NaN
# 16894    Unnamed: 47  NaN  2024-04-01 00:00:00           NaN
#
# [1056 rows x 4 columns]

# %%
NaNFreeDF1 = clean_properties[clean_properties['Average_price'].notna()]
NaNFreeDF1.head(48)
# Out:
#           London_Borough         ID                Month Average_price
# 0         City of London  E09000001  1995-01-01 00:00:00   91448.98487
# 1     Barking & Dagenham  E09000002  1995-01-01 00:00:00    50460.2266
# 2                 Barnet  E09000003  1995-01-01 00:00:00   93284.51832
# 3                 Bexley  E09000004  1995-01-01 00:00:00   64958.09036
# 4                  Brent  E09000005  1995-01-01 00:00:00   71306.56698
# 5                Bromley  E09000006  1995-01-01 00:00:00   81671.47692
# 6                 Camden  E09000007  1995-01-01 00:00:00   120932.8881
# 7                Croydon  E09000008  1995-01-01 00:00:00   69158.16225
# 8                 Ealing  E09000009  1995-01-01 00:00:00   79885.89069
# 9                Enfield  E09000010  1995-01-01 00:00:00   72514.69096
# 10             Greenwich  E09000011  1995-01-01 00:00:00   62300.10169
# 11               Hackney  E09000012  1995-01-01 00:00:00   61296.52637
# 12  Hammersmith & Fulham  E09000013  1995-01-01 00:00:00   124902.8602
# 13              Haringey  E09000014  1995-01-01 00:00:00   76287.56947
# 14                Harrow  E09000015  1995-01-01 00:00:00   84769.52599
# 15              Havering  E09000016  1995-01-01 00:00:00   68000.13774
# 16            Hillingdon  E09000017  1995-01-01 00:00:00   73834.82964
# 17              Hounslow  E09000018  1995-01-01 00:00:00   72231.70537
# 18             Islington  E09000019  1995-01-01 00:00:00   92516.48557
# 19  Kensington & Chelsea  E09000020  1995-01-01 00:00:00   182694.8326
# 20  Kingston upon Thames  E09000021  1995-01-01 00:00:00   80875.84843
# 21               Lambeth  E09000022  1995-01-01 00:00:00   67770.98843
# 22              Lewisham  E09000023  1995-01-01 00:00:00   60491.26109
# 23                Merton  E09000024  1995-01-01 00:00:00    82070.6133
# 24                Newham  E09000025  1995-01-01 00:00:00   53539.31919
# 25             Redbridge  E09000026  1995-01-01 00:00:00   72189.58437
# 26  Richmond upon Thames  E09000027  1995-01-01 00:00:00   109326.1245
# 27             Southwark  E09000028  1995-01-01 00:00:00   67885.20344
# 28                Sutton  E09000029  1995-01-01 00:00:00   71536.97357
# 29         Tower Hamlets  E09000030  1995-01-01 00:00:00   59865.18995
# 30        Waltham Forest  E09000031  1995-01-01 00:00:00   61319.44913
# 31            Wandsworth  E09000032  1995-01-01 00:00:00   88559.04381
# 32           Westminster  E09000033  1995-01-01 00:00:00   133025.2772
# 34          Inner London  E13000001  1995-01-01 00:00:00    78251.9765
# 35          Outer London  E13000002  1995-01-01 00:00:00   72958.79836
# 37            NORTH EAST  E12000001  1995-01-01 00:00:00   42076.35411
# 38            NORTH WEST  E12000002  1995-01-01 00:00:00   43958.48001
# 39    YORKS & THE HUMBER  E12000003  1995-01-01 00:00:00   44803.42878
# 40         EAST MIDLANDS  E12000004  1995-01-01 00:00:00   45544.52227
# 41         WEST MIDLANDS  E12000005  1995-01-01 00:00:00   48527.52339
# 42       EAST OF ENGLAND  E12000006  1995-01-01 00:00:00    56701.5961
# 43                LONDON  E12000007  1995-01-01 00:00:00   74435.76052
# 44            SOUTH EAST  E12000008  1995-01-01 00:00:00   64018.87894
# 45            SOUTH WEST  E12000009  1995-01-01 00:00:00    54705.1579
# 47               England  E92000001  1995-01-01 00:00:00   53202.77128
# 48        City of London  E09000001  1995-02-01 00:00:00   82202.77314
# 49    Barking & Dagenham  E09000002  1995-02-01 00:00:00   51085.77983
# 50                Barnet  E09000003  1995-02-01 00:00:00   93190.16963

# %%
nonBoroughs = ['Inner London', 'Outer London', 
               'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER', 
               'EAST MIDLANDS', 'WEST MIDLANDS',
              'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST', 
              'SOUTH WEST', 'England']

# %%
NaNFreeDF1 = NaNFreeDF1[~NaNFreeDF1.London_Borough.isin(nonBoroughs)]

# %%
df = NaNFreeDF1

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %%
camden_prices = df[df['London_Borough'] == 'Camden']
ax = camden_prices.plot(kind ='line', x = 'Month', y='Average_price')
ax.set_ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
df['Year'] = df['Month'].apply(lambda t: t.year)
df.tail()
# Out:
#        London_Borough         ID                Month Average_price  Year
# 16876          Sutton  E09000029  2024-04-01 00:00:00        420492  2024
# 16877   Tower Hamlets  E09000030  2024-04-01 00:00:00        440574  2024
# 16878  Waltham Forest  E09000031  2024-04-01 00:00:00        477622  2024
# 16879      Wandsworth  E09000032  2024-04-01 00:00:00        620731  2024
# 16880     Westminster  E09000033  2024-04-01 00:00:00        969527  2024

# %%
dfg = df.groupby(by=['London_Borough', 'Year'])['Average_price'].mean().reset_index()
dfg.sample(30)
# Out:
#            London_Borough  Year  Average_price
# 504            Hillingdon  2019  404350.695467
# 674              Lewisham  2009  211307.586542
# 45                 Barnet  2010    333128.0967
# 933            Wandsworth  1998  125406.807233
# 938            Wandsworth  2003  253342.476767
# 468              Havering  2013  226428.817033
# 291               Enfield  2016  385489.805458
# 860                Sutton  2015  322932.138442
# 715                Merton  2020  524124.826575
# 287               Enfield  2012  247667.148392
# 520              Hounslow  2005   222920.92745
# 258                Ealing  2013  338088.966475
# 387  Hammersmith & Fulham  2022      775288.75
# 534              Hounslow  2019   401792.39535
# 829             Southwark  2014  427767.413767
# 600  Kingston upon Thames  1995   82838.986157
# 14     Barking & Dagenham  2009  156446.896358
# 745                Newham  2020   373780.22085
# 773             Redbridge  2018  422591.065915
# 327             Greenwich  2022       443286.5
# 426                Harrow  2001  170250.168608
# 671              Lewisham  2006   202362.10065
# 833             Southwark  2018  504235.374945
# 313             Greenwich  2008  231136.204225
# 764             Redbridge  2009  232764.076092
# 812             Southwark  1997    79725.85014
# 344               Hackney  2009  282240.752267
# 969           Westminster  2004  379395.350458
# 295               Enfield  2020  396768.997492
# 526              Hounslow  2011  264605.140442

# %%
dfg.reset_index()
dfg.head()
# Out:
#        London_Borough  Year Average_price
# 0  Barking & Dagenham  1995   51817.96939
# 1  Barking & Dagenham  1996   51718.19269
# 2  Barking & Dagenham  1997  55974.262309
# 3  Barking & Dagenham  1998  60285.821083
# 4  Barking & Dagenham  1999  65320.934441

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
def create_price_ratio(d):
    y1998 = float(d['Average_price'][d['Year']==1998])
    y2024 = float(d['Average_price'][d['Year']==2024])
    ratio = [y1998/y2024]
    return ratio

# %%
create_price_ratio(dfg[dfg['London_Borough']=='Barking & Dagenham'])
# Out:
# C:\Users\jmalo\AppData\Local\Temp\ipykernel_24468\2682992494.py:2: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   y1998 = float(d['Average_price'][d['Year']==1998])
# C:\Users\jmalo\AppData\Local\Temp\ipykernel_24468\2682992494.py:3: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   y2024 = float(d['Average_price'][d['Year']==2024])
# [0.18432606506079785]

# %%
final = {}

# %%
for b in dfg['London_Borough'].unique():
    # Let's make our parameter to our create_price_ratio function: i.e., we subset dfg on 'London_Borough' == b. 
    borough = dfg[dfg['London_Borough'] == b]
    # Make a new entry in the final dictionary whose value's the result of calling create_price_ratio with the argument: borough
    final[b] = create_price_ratio(borough)
# We use the function and incorporate that into a new key of the dictionary 
print(final)
# Out:
# {'Barking & Dagenham': [0.18432606506079785], 'Barnet': [0.21185218767133562], 'Bexley': [0.2021346590248662], 'Brent': [0.19674043429038868], 'Bromley': [0.22043382923547808], 'Camden': [0.21868230459318022], 'City of London': [0.189857563173089], 'Croydon': [0.2242768902122906], 'Ealing': [0.21429958778234406], 'Enfield': [0.22085348596947915], 'Greenwich': [0.18381862145690878], 'Hackney': [0.14950771819027273], 'Hammersmith & Fulham': [0.23258064639146406], 'Haringey': [0.19255381096615978], 'Harrow': [0.22507580357369011], 'Havering': [0.20768888182523987], 'Hillingdon': [0.21854251873654285], 'Hounslow': [0.2190791278714773], 'Islington': [0.19957313976400645], 'Kensington & Chelsea': [0.224152748013849], 'Kingston upon Thames': [0.21877795010543435], 'Lambeth': [0.20367783754458], 'Lewisham': [0.17651527884440316], 'Merton': [0.1978212267068473], 'Newham': [0.17007682030553942], 'Redbridge': [0.20207819303688312], 'Richmond upon Thames': [0.22446025107757916], 'Southwark': [0.19082482748800192], 'Sutton': [0.21729879405997876], 'Tower Hamlets': [0.21824687354156513], 'Waltham Forest': [0.15451631592580814], 'Wandsworth': [0.20261987042618687], 'Westminster': [0.19647603774972805]}
# C:\Users\jmalo\AppData\Local\Temp\ipykernel_24468\2682992494.py:2: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   y1998 = float(d['Average_price'][d['Year']==1998])
# C:\Users\jmalo\AppData\Local\Temp\ipykernel_24468\2682992494.py:3: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   y2024 = float(d['Average_price'][d['Year']==2024])

# %%
df_ratios=pd.DataFrame(final)

# %%
df_ratios.head()
# Out:
#    Barking & Dagenham    Barnet    Bexley    Brent   Bromley    Camden  \
# 0            0.184326  0.211852  0.202135  0.19674  0.220434  0.218682
#
#    City of London   Croydon  Ealing   Enfield  ...    Merton    Newham  \
# 0        0.189858  0.224277  0.2143  0.220853  ...  0.197821  0.170077
#
#    Redbridge  Richmond upon Thames  Southwark    Sutton  Tower Hamlets  \
# 0   0.202078               0.22446   0.190825  0.217299       0.218247
#
#    Waltham Forest  Wandsworth  Westminster
# 0        0.154516     0.20262     0.196476
#
# [1 rows x 33 columns]

# %%
df_ratios_T = df_ratios.T
df_ratios = df_ratios_T.reset_index()
df_ratios.head()
# Out:
#                 index         0
# 0  Barking & Dagenham  0.184326
# 1              Barnet  0.211852
# 2              Bexley  0.202135
# 3               Brent  0.196740
# 4             Bromley  0.220434

# %%
df_ratios.rename(columns={'index':'Borough', 0:'2024'}, inplace=True)
df_ratios.head()
# Out:
#               Borough      2024
# 0  Barking & Dagenham  0.184326
# 1              Barnet  0.211852
# 2              Bexley  0.202135
# 3               Brent  0.196740
# 4             Bromley  0.220434

# %%
top15= df_ratios.sort_values(by='2024',ascending=False).head(15)
print(top15)
# Out:
#                  Borough      2024
# 12  Hammersmith & Fulham  0.232581
# 14                Harrow  0.225076
# 26  Richmond upon Thames  0.224460
# 7                Croydon  0.224277
# 19  Kensington & Chelsea  0.224153
# 9                Enfield  0.220853
# 4                Bromley  0.220434
# 17              Hounslow  0.219079
# 20  Kingston upon Thames  0.218778
# 5                 Camden  0.218682
# 16            Hillingdon  0.218543
# 29         Tower Hamlets  0.218247
# 28                Sutton  0.217299
# 8                 Ealing  0.214300
# 1                 Barnet  0.211852

# %%
ax = top15[['Borough','2024']].plot(kind='bar')
ax.set_xticklabels(top15.Borough)
# Out:
# [Text(0, 0, 'Hammersmith & Fulham'),
#  Text(1, 0, 'Harrow'),
#  Text(2, 0, 'Richmond upon Thames'),
#  Text(3, 0, 'Croydon'),
#  Text(4, 0, 'Kensington & Chelsea'),
#  Text(5, 0, 'Enfield'),
#  Text(6, 0, 'Bromley'),
#  Text(7, 0, 'Hounslow'),
#  Text(8, 0, 'Kingston upon Thames'),
#  Text(9, 0, 'Camden'),
#  Text(10, 0, 'Hillingdon'),
#  Text(11, 0, 'Tower Hamlets'),
#  Text(12, 0, 'Sutton'),
#  Text(13, 0, 'Ealing'),
#  Text(14, 0, 'Barnet')]

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!
